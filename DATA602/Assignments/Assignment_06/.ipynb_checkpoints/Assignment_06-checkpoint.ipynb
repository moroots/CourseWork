# %% [markdown]
# ### Assignment 06: Model Evaluation
#
# using the attached file, you are going to get experience using grid search and cross-validation.
#
# Directions:
#
# Create a new repo in your GitHub for DATA602. It should contain:
# - a brief readme
# - data folder with the attached data
# - your notebook
#
# Using the attached data, create a Jupyter Notebook
# - Inspect the data and create a pipeline to perform any feature processing
# - Prior to building the feature pipeline, be sure to split the data into training/test sets
# - Create a logistic regression model pipeline that uses the above pipeline
# - Pick a metric you are going to use to select the model and justify your choice.
# - Use the above combined pipeline to run a Logistic Regression model with grid search cross-validation using 10 folds. Search 5 different regularization strengths and 2 solvers. What is the best model? How does it perform on the test set?
#
#
# _The variable you should be predicting in the 'Class' column._
#
#
# Submit a link to your Github repo.

# %%
# --- Importing the Data and Modules --- #
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

df = pd.read_csv("data/pima_indian_data.csv")
df.head(10)
# Out:
#    Number  of times pregnant  Plasma glucose  Diastolic blood pressure  \
# 0                          6             148                        72
# 1                          1              85                        66
# 2                          8             183                        64
# 3                          1              89                        66
# 4                          0             137                        40
# 5                          5             116                        74
# 6                          3              78                        50
# 7                         10             115                         0
# 8                          2             197                        70
# 9                          8             125                        96
#
#    Triceps skinfold thickness  serum insulin  Body mass index  \
# 0                          35              0             33.6
# 1                          29              0             26.6
# 2                           0              0             23.3
# 3                          23             94             28.1
# 4                          35            168             43.1
# 5                           0              0             25.6
# 6                          32             88             31.0
# 7                           0              0             35.3
# 8                          45            543             30.5
# 9                           0              0              0.0
#
#    Diabetes pedigree function  Age  Class
# 0                       0.627   50      1
# 1                       0.351   31      0
# 2                       0.672   32      1
# 3                       0.167   21      0
# 4                       2.288   33      1
# 5                       0.201   30      0
# 6                       0.248   26      1
# 7                       0.134   29      0
# 8                       0.158   53      1
# 9                       0.232   54      1

# %% [markdown]
# _Table 1: Shown here is the raw imported data from the provided dataset. A detailed description of the data can be fouind in the ReadMe_Assignment_06.md file of this directory. The "Class" columnn is the objective for a binary classification model._

# %%
print(df.isna().sum().sum())
df.info()
# Out:
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Number  of times pregnant   768 non-null    int64
#  1   Plasma glucose              768 non-null    int64
#  2   Diastolic blood pressure    768 non-null    int64
#  3   Triceps skinfold thickness  768 non-null    int64
#  4   serum insulin               768 non-null    int64
#  5   Body mass index             768 non-null    float64
#  6   Diabetes pedigree function  768 non-null    float64
#  7   Age                         768 non-null    int64
#  8   Class                       768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# _Table 2: Shown here is the data types (Dtype), number of values (non-null count) for each column of Table 1. Notice each column is numeric 64-bit integer of float with no null values._

# %% [markdown]
# First I have imported some necessary standard packages/modules (numpy, matplotlib, and pandas). These will assist in the exploritory data analysis (EDA) and completion of a working regression model for the dataset.

# %%
x = df.drop(columns=["Class"])
y = df.Class
x_names = df.columns

df.describe().T
# Out:
#                             count        mean         std     min       25%  \
# Number  of times pregnant   768.0    3.845052    3.369578   0.000   1.00000
# Plasma glucose              768.0  120.894531   31.972618   0.000  99.00000
# Diastolic blood pressure    768.0   69.105469   19.355807   0.000  62.00000
# Triceps skinfold thickness  768.0   20.536458   15.952218   0.000   0.00000
# serum insulin               768.0   79.799479  115.244002   0.000   0.00000
# Body mass index             768.0   31.992578    7.884160   0.000  27.30000
# Diabetes pedigree function  768.0    0.471876    0.331329   0.078   0.24375
# Age                         768.0   33.240885   11.760232  21.000  24.00000
# Class                       768.0    0.348958    0.476951   0.000   0.00000
#
#                                  50%        75%     max
# Number  of times pregnant     3.0000    6.00000   17.00
# Plasma glucose              117.0000  140.25000  199.00
# Diastolic blood pressure     72.0000   80.00000  122.00
# Triceps skinfold thickness   23.0000   32.00000   99.00
# serum insulin                30.5000  127.25000  846.00
# Body mass index              32.0000   36.60000   67.10
# Diabetes pedigree function    0.3725    0.62625    2.42
# Age                          29.0000   41.00000   81.00
# Class                         0.0000    1.00000    1.00

# %% [markdown]
# _Table 3: Shown here is a brief statistical description of the dataset showing the number of values (count), the mean value, standard deviation (std), minimum value (min), and percentieles of 25%, 50%, and 75%, as well as the maximum (max) value for each column._

# %%
df.hist(figsize=(14,14))
plt.show()

# %% [markdown]
# _Figure 1: shown here is a histogram of each column in the dataset._

# %% [markdown]
# There do not seem to be any obvious issues with data quality. Also note that the values are all on different scates, I will need to standardize the dataset.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# _Figure 2: Shown here is the correlation heatmap for the dataset._

# %% [markdown]
# There may be some multicolinearity in the dataset, therefore a Principal Component Analysis (PCA) will be encorporated in the pipeline.

# %% [markdown]
# ### Pipeline Gameplan
# - Establish the Training and Test sets from the data
# - Create the data processing pipeline
#     - standardize the data features
#     - extract a 3 component PCA
# - Perform the Logistic Regression
#     - two solvers: 'liblinear' (penalty = l2) and 'lbfgs' (penalty = none)
# - Evaluate the model "accuracy"
#     - F1-Score
#     - ROC AUC
#     -Refit with ROC AUC

# %%
# --- Splitting the Data --- #
from sklearn.model_selection import train_test_split as tts

def create_splits(x, y): 
    return tts(x,y,test_size=0.20, random_state=1)

x_train, x_test, y_train, y_test = create_splits(x,y)

print(f"Training Sample: {x_train.shape[0]:,}")
print(f"Test Sample: {x_test.shape[0]:,}")
# Out:
# Training Sample: 614
# Test Sample: 154

# %% [markdown]
# The above code splits the dataset into a training-set and test-set which

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

lg_pipe = modeling_pipeline = Pipeline([
        ('scaler', StandardScaler()),
         ('pca', PCA(n_components=3)),
         ('logreg', LogisticRegression(penalty='l2', solver='liblinear', random_state=1))
        ]
    )
        
param_grid = [{'logreg__C': [1, 10, 100, 1000, 10000], 'pca__n_components': [1,2,3,4,5,6,7,8]}]

gcv_results = GridSearchCV(estimator=lg_pipe, param_grid=param_grid, scoring=['f1_macro', 'roc_auc'], refit="roc_auc", cv=10)
gcv_results = gcv_results.fit(x_train, y_train)

# %%
pd.DataFrame.from_dict(gcv_results.cv_results_).T
# Out:
#                                                                0   \
# mean_fit_time                                            0.005196
# std_fit_time                                             0.000741
# mean_score_time                                          0.004415
# std_score_time                                            0.00069
# param_logreg__C                                                 1
# param_pca__n_components                                         1
# params                   {'logreg__C': 1, 'pca__n_components': 1}
# split0_test_f1_macro                                      0.69031
# split1_test_f1_macro                                     0.594771
# split2_test_f1_macro                                     0.634048
# split3_test_f1_macro                                     0.634409
# split4_test_f1_macro                                      0.46992
# split5_test_f1_macro                                      0.61875
# split6_test_f1_macro                                     0.688458
# split7_test_f1_macro                                      0.61875
# split8_test_f1_macro                                     0.582827
# split9_test_f1_macro                                     0.660734
# mean_test_f1_macro                                       0.619298
# std_test_f1_macro                                        0.060195
# rank_test_f1_macro                                             36
# split0_test_roc_auc                                      0.818182
# split1_test_roc_auc                                      0.628409
# split2_test_roc_auc                                      0.703409
# split3_test_roc_auc                                      0.788618
# split4_test_roc_auc                                      0.590476
# split5_test_roc_auc                                      0.770238
# split6_test_roc_auc                                       0.74881
# split7_test_roc_auc                                      0.689286
# split8_test_roc_auc                                      0.721429
# split9_test_roc_auc                                      0.710714
# mean_test_roc_auc                                        0.716957
# std_test_roc_auc                                         0.066394
# rank_test_roc_auc                                              36
#
#                                                                1   \
# mean_fit_time                                             0.00531
# std_fit_time                                             0.000919
# mean_score_time                                          0.004592
# std_score_time                                           0.000483
# param_logreg__C                                                 1
# param_pca__n_components                                         2
# params                   {'logreg__C': 1, 'pca__n_components': 2}
# split0_test_f1_macro                                     0.732989
# split1_test_f1_macro                                     0.644646
# split2_test_f1_macro                                      0.60724
# split3_test_f1_macro                                     0.705163
# split4_test_f1_macro                                      0.57931
# split5_test_f1_macro                                     0.717331
# split6_test_f1_macro                                     0.688458
# split7_test_f1_macro                                     0.534028
# split8_test_f1_macro                                      0.61875
# split9_test_f1_macro                                     0.763566
# mean_test_f1_macro                                       0.659148
# std_test_f1_macro                                        0.070202
# rank_test_f1_macro                                             26
# split0_test_roc_auc                                      0.853409
# split1_test_roc_auc                                      0.746591
# split2_test_roc_auc                                        0.6875
# split3_test_roc_auc                                      0.821138
# split4_test_roc_auc                                      0.642857
# split5_test_roc_auc                                      0.764286
# split6_test_roc_auc                                      0.790476
# split7_test_roc_auc                                      0.613095
# split8_test_roc_auc                                      0.770238
# split9_test_roc_auc                                      0.828571
# mean_test_roc_auc                                        0.751816
# std_test_roc_auc                                         0.076346
# rank_test_roc_auc                                              31
#
#                                                                2   \
# mean_fit_time                                            0.004898
# std_fit_time                                             0.000714
# mean_score_time                                          0.004145
# std_score_time                                           0.000706
# param_logreg__C                                                 1
# param_pca__n_components                                         3
# params                   {'logreg__C': 1, 'pca__n_components': 3}
# split0_test_f1_macro                                     0.741667
# split1_test_f1_macro                                     0.595527
# split2_test_f1_macro                                     0.594048
# split3_test_f1_macro                                      0.71634
# split4_test_f1_macro                                     0.566537
# split5_test_f1_macro                                     0.730645
# split6_test_f1_macro                                     0.646919
# split7_test_f1_macro                                     0.592246
# split8_test_f1_macro                                       0.6324
# split9_test_f1_macro                                     0.755348
# mean_test_f1_macro                                       0.657167
# std_test_f1_macro                                        0.068272
# rank_test_f1_macro                                             31
# split0_test_roc_auc                                      0.881818
# split1_test_roc_auc                                      0.756818
# split2_test_roc_auc                                      0.745455
# split3_test_roc_auc                                      0.817654
# split4_test_roc_auc                                      0.654762
# split5_test_roc_auc                                      0.820238
# split6_test_roc_auc                                           0.8
# split7_test_roc_auc                                      0.691667
# split8_test_roc_auc                                      0.855952
# split9_test_roc_auc                                      0.835714
# mean_test_roc_auc                                        0.786008
# std_test_roc_auc                                         0.068945
# rank_test_roc_auc                                              30
#
#                                                                3   \
# mean_fit_time                                            0.004889
# std_fit_time                                             0.000721
# mean_score_time                                          0.004504
# std_score_time                                           0.000805
# param_logreg__C                                                 1
# param_pca__n_components                                         4
# params                   {'logreg__C': 1, 'pca__n_components': 4}
# split0_test_f1_macro                                      0.76315
# split1_test_f1_macro                                     0.608586
# split2_test_f1_macro                                     0.582619
# split3_test_f1_macro                                     0.765152
# split4_test_f1_macro                                     0.592687
# split5_test_f1_macro                                     0.651009
# split6_test_f1_macro                                     0.633021
# split7_test_f1_macro                                      0.67027
# split8_test_f1_macro                                     0.646919
# split9_test_f1_macro                                     0.714572
# mean_test_f1_macro                                       0.662798
# std_test_f1_macro                                        0.062325
# rank_test_f1_macro                                             21
# split0_test_roc_auc                                      0.888636
# split1_test_roc_auc                                      0.781818
# split2_test_roc_auc                                      0.693182
# split3_test_roc_auc                                      0.861789
# split4_test_roc_auc                                       0.67381
# split5_test_roc_auc                                      0.808333
# split6_test_roc_auc                                      0.819048
# split7_test_roc_auc                                      0.702381
# split8_test_roc_auc                                      0.861905
# split9_test_roc_auc                                      0.829762
# mean_test_roc_auc                                        0.792066
# std_test_roc_auc                                         0.073068
# rank_test_roc_auc                                              22
#
#                                                                4   \
# mean_fit_time                                            0.004593
# std_fit_time                                             0.000669
# mean_score_time                                          0.004304
# std_score_time                                           0.000792
# param_logreg__C                                                 1
# param_pca__n_components                                         5
# params                   {'logreg__C': 1, 'pca__n_components': 5}
# split0_test_f1_macro                                     0.799589
# split1_test_f1_macro                                     0.608586
# split2_test_f1_macro                                     0.582619
# split3_test_f1_macro                                     0.741252
# split4_test_f1_macro                                     0.645349
# split5_test_f1_macro                                     0.679642
# split6_test_f1_macro                                     0.673797
# split7_test_f1_macro                                     0.709062
# split8_test_f1_macro                                     0.646919
# split9_test_f1_macro                                      0.72416
# mean_test_f1_macro                                       0.681097
# std_test_f1_macro                                        0.061443
# rank_test_f1_macro                                             16
# split0_test_roc_auc                                      0.894318
# split1_test_roc_auc                                      0.780682
# split2_test_roc_auc                                      0.693182
# split3_test_roc_auc                                      0.858304
# split4_test_roc_auc                                          0.75
# split5_test_roc_auc                                      0.830952
# split6_test_roc_auc                                      0.811905
# split7_test_roc_auc                                      0.707143
# split8_test_roc_auc                                      0.819048
# split9_test_roc_auc                                      0.842857
# mean_test_roc_auc                                        0.798839
# std_test_roc_auc                                         0.062038
# rank_test_roc_auc                                              16
#
#                                                                5   \
# mean_fit_time                                            0.005103
# std_fit_time                                             0.000945
# mean_score_time                                          0.004389
# std_score_time                                           0.000795
# param_logreg__C                                                 1
# param_pca__n_components                                         6
# params                   {'logreg__C': 1, 'pca__n_components': 6}
# split0_test_f1_macro                                     0.819977
# split1_test_f1_macro                                     0.635294
# split2_test_f1_macro                                     0.682955
# split3_test_f1_macro                                     0.765152
# split4_test_f1_macro                                     0.694236
# split5_test_f1_macro                                     0.825515
# split6_test_f1_macro                                      0.72416
# split7_test_f1_macro                                     0.679642
# split8_test_f1_macro                                     0.699507
# split9_test_f1_macro                                     0.739634
# mean_test_f1_macro                                       0.726607
# std_test_f1_macro                                        0.058646
# rank_test_f1_macro                                              6
# split0_test_roc_auc                                      0.890909
# split1_test_roc_auc                                      0.761364
# split2_test_roc_auc                                      0.744318
# split3_test_roc_auc                                      0.843206
# split4_test_roc_auc                                       0.74881
# split5_test_roc_auc                                      0.908333
# split6_test_roc_auc                                      0.861905
# split7_test_roc_auc                                      0.769048
# split8_test_roc_auc                                      0.870238
# split9_test_roc_auc                                      0.863095
# mean_test_roc_auc                                        0.826123
# std_test_roc_auc                                         0.059968
# rank_test_roc_auc                                               5
#
#                                                                6   \
# mean_fit_time                                              0.0048
# std_fit_time                                             0.000973
# mean_score_time                                          0.003902
# std_score_time                                           0.000539
# param_logreg__C                                                 1
# param_pca__n_components                                         7
# params                   {'logreg__C': 1, 'pca__n_components': 7}
# split0_test_f1_macro                                     0.819977
# split1_test_f1_macro                                      0.62183
# split2_test_f1_macro                                     0.639954
# split3_test_f1_macro                                     0.749612
# split4_test_f1_macro                                     0.684755
# split5_test_f1_macro                                     0.809645
# split6_test_f1_macro                                     0.739573
# split7_test_f1_macro                                     0.709062
# split8_test_f1_macro                                     0.729997
# split9_test_f1_macro                                     0.739634
# mean_test_f1_macro                                       0.724404
# std_test_f1_macro                                        0.060819
# rank_test_f1_macro                                             11
# split0_test_roc_auc                                      0.897727
# split1_test_roc_auc                                      0.768182
# split2_test_roc_auc                                      0.740909
# split3_test_roc_auc                                      0.837398
# split4_test_roc_auc                                      0.708333
# split5_test_roc_auc                                           0.9
# split6_test_roc_auc                                      0.861905
# split7_test_roc_auc                                      0.777381
# split8_test_roc_auc                                      0.858333
# split9_test_roc_auc                                          0.85
# mean_test_roc_auc                                        0.820017
# std_test_roc_auc                                         0.063321
# rank_test_roc_auc                                              15
#
#                                                                7   \
# mean_fit_time                                            0.004402
# std_fit_time                                             0.000676
# mean_score_time                                          0.004389
# std_score_time                                           0.000795
# param_logreg__C                                                 1
# param_pca__n_components                                         8
# params                   {'logreg__C': 1, 'pca__n_components': 8}
# split0_test_f1_macro                                     0.819977
# split1_test_f1_macro                                     0.635294
# split2_test_f1_macro                                     0.667857
# split3_test_f1_macro                                     0.788133
# split4_test_f1_macro                                      0.67027
# split5_test_f1_macro                                     0.854762
# split6_test_f1_macro                                      0.72416
# split7_test_f1_macro                                     0.694236
# split8_test_f1_macro                                     0.714572
# split9_test_f1_macro                                     0.761217
# mean_test_f1_macro                                       0.733048
# std_test_f1_macro                                        0.067729
# rank_test_f1_macro                                              5
# split0_test_roc_auc                                      0.902273
# split1_test_roc_auc                                        0.7875
# split2_test_roc_auc                                      0.753409
# split3_test_roc_auc                                      0.837398
# split4_test_roc_auc                                      0.707143
# split5_test_roc_auc                                      0.916667
# split6_test_roc_auc                                       0.85119
# split7_test_roc_auc                                      0.767857
# split8_test_roc_auc                                      0.858333
# split9_test_roc_auc                                      0.858333
# mean_test_roc_auc                                         0.82401
# std_test_roc_auc                                         0.064119
# rank_test_roc_auc                                               6
#
#                                                                 8   \
# mean_fit_time                                             0.004593
# std_fit_time                                              0.000484
# mean_score_time                                             0.0043
# std_score_time                                            0.000781
# param_logreg__C                                                 10
# param_pca__n_components                                          1
# params                   {'logreg__C': 10, 'pca__n_components': 1}
# split0_test_f1_macro                                       0.69031
# split1_test_f1_macro                                      0.594771
# split2_test_f1_macro                                      0.634048
# split3_test_f1_macro                                      0.634409
# split4_test_f1_macro                                       0.46992
# split5_test_f1_macro                                       0.61875
# split6_test_f1_macro                                      0.688458
# split7_test_f1_macro                                       0.61875
# split8_test_f1_macro                                      0.582827
# split9_test_f1_macro                                      0.660734
# mean_test_f1_macro                                        0.619298
# std_test_f1_macro                                         0.060195
# rank_test_f1_macro                                              36
# split0_test_roc_auc                                       0.818182
# split1_test_roc_auc                                       0.628409
# split2_test_roc_auc                                       0.703409
# split3_test_roc_auc                                       0.788618
# split4_test_roc_auc                                       0.590476
# split5_test_roc_auc                                       0.770238
# split6_test_roc_auc                                        0.74881
# split7_test_roc_auc                                       0.689286
# split8_test_roc_auc                                       0.721429
# split9_test_roc_auc                                       0.710714
# mean_test_roc_auc                                         0.716957
# std_test_roc_auc                                          0.066394
# rank_test_roc_auc                                               36
#
#                                                                 9   ...  \
# mean_fit_time                                               0.0051  ...
# std_fit_time                                              0.000832  ...
# mean_score_time                                             0.0045  ...
# std_score_time                                            0.000805  ...
# param_logreg__C                                                 10  ...
# param_pca__n_components                                          2  ...
# params                   {'logreg__C': 10, 'pca__n_components': 2}  ...
# split0_test_f1_macro                                      0.732989  ...
# split1_test_f1_macro                                      0.644646  ...
# split2_test_f1_macro                                       0.60724  ...
# split3_test_f1_macro                                      0.705163  ...
# split4_test_f1_macro                                       0.57931  ...
# split5_test_f1_macro                                      0.717331  ...
# split6_test_f1_macro                                      0.688458  ...
# split7_test_f1_macro                                      0.534028  ...
# split8_test_f1_macro                                       0.61875  ...
# split9_test_f1_macro                                      0.763566  ...
# mean_test_f1_macro                                        0.659148  ...
# std_test_f1_macro                                         0.070202  ...
# rank_test_f1_macro                                              26  ...
# split0_test_roc_auc                                       0.853409  ...
# split1_test_roc_auc                                       0.746591  ...
# split2_test_roc_auc                                         0.6875  ...
# split3_test_roc_auc                                       0.821138  ...
# split4_test_roc_auc                                       0.642857  ...
# split5_test_roc_auc                                       0.764286  ...
# split6_test_roc_auc                                       0.790476  ...
# split7_test_roc_auc                                       0.613095  ...
# split8_test_roc_auc                                       0.770238  ...
# split9_test_roc_auc                                       0.828571  ...
# mean_test_roc_auc                                         0.751816  ...
# std_test_roc_auc                                          0.076346  ...
# rank_test_roc_auc                                               31  ...
#
#                                                                   30  \
# mean_fit_time                                               0.004004
# std_fit_time                                                0.000632
# mean_score_time                                             0.003691
# std_score_time                                              0.000454
# param_logreg__C                                                 1000
# param_pca__n_components                                            7
# params                   {'logreg__C': 1000, 'pca__n_components': 7}
# split0_test_f1_macro                                        0.819977
# split1_test_f1_macro                                         0.62183
# split2_test_f1_macro                                        0.639954
# split3_test_f1_macro                                        0.749612
# split4_test_f1_macro                                        0.684755
# split5_test_f1_macro                                        0.790618
# split6_test_f1_macro                                        0.739573
# split7_test_f1_macro                                        0.709062
# split8_test_f1_macro                                        0.729997
# split9_test_f1_macro                                        0.739634
# mean_test_f1_macro                                          0.722501
# std_test_f1_macro                                           0.058371
# rank_test_f1_macro                                                13
# split0_test_roc_auc                                         0.897727
# split1_test_roc_auc                                         0.768182
# split2_test_roc_auc                                         0.742045
# split3_test_roc_auc                                         0.836237
# split4_test_roc_auc                                         0.709524
# split5_test_roc_auc                                              0.9
# split6_test_roc_auc                                         0.864286
# split7_test_roc_auc                                         0.778571
# split8_test_roc_auc                                         0.858333
# split9_test_roc_auc                                             0.85
# mean_test_roc_auc                                           0.820491
# std_test_roc_auc                                            0.063021
# rank_test_roc_auc                                                 11
#
#                                                                   31  \
# mean_fit_time                                               0.004005
# std_fit_time                                                0.000624
# mean_score_time                                             0.003798
# std_score_time                                              0.000888
# param_logreg__C                                                 1000
# param_pca__n_components                                            8
# params                   {'logreg__C': 1000, 'pca__n_components': 8}
# split0_test_f1_macro                                        0.819977
# split1_test_f1_macro                                        0.635294
# split2_test_f1_macro                                        0.667857
# split3_test_f1_macro                                        0.788133
# split4_test_f1_macro                                         0.67027
# split5_test_f1_macro                                        0.871424
# split6_test_f1_macro                                         0.72416
# split7_test_f1_macro                                        0.694236
# split8_test_f1_macro                                        0.714572
# split9_test_f1_macro                                        0.761217
# mean_test_f1_macro                                          0.734714
# std_test_f1_macro                                           0.070837
# rank_test_f1_macro                                                 1
# split0_test_roc_auc                                         0.902273
# split1_test_roc_auc                                           0.7875
# split2_test_roc_auc                                         0.751136
# split3_test_roc_auc                                         0.832753
# split4_test_roc_auc                                         0.707143
# split5_test_roc_auc                                         0.916667
# split6_test_roc_auc                                          0.85119
# split7_test_roc_auc                                         0.767857
# split8_test_roc_auc                                         0.858333
# split9_test_roc_auc                                         0.855952
# mean_test_roc_auc                                            0.82308
# std_test_roc_auc                                            0.064164
# rank_test_roc_auc                                                  8
#
#                                                                    32  \
# mean_fit_time                                                0.004516
# std_fit_time                                                  0.00066
# mean_score_time                                              0.003799
# std_score_time                                               0.000761
# param_logreg__C                                                 10000
# param_pca__n_components                                             1
# params                   {'logreg__C': 10000, 'pca__n_components': 1}
# split0_test_f1_macro                                          0.69031
# split1_test_f1_macro                                         0.594771
# split2_test_f1_macro                                         0.634048
# split3_test_f1_macro                                         0.634409
# split4_test_f1_macro                                          0.46992
# split5_test_f1_macro                                          0.61875
# split6_test_f1_macro                                         0.688458
# split7_test_f1_macro                                          0.61875
# split8_test_f1_macro                                         0.582827
# split9_test_f1_macro                                         0.660734
# mean_test_f1_macro                                           0.619298
# std_test_f1_macro                                            0.060195
# rank_test_f1_macro                                                 36
# split0_test_roc_auc                                          0.818182
# split1_test_roc_auc                                          0.628409
# split2_test_roc_auc                                          0.703409
# split3_test_roc_auc                                          0.788618
# split4_test_roc_auc                                          0.590476
# split5_test_roc_auc                                          0.770238
# split6_test_roc_auc                                           0.74881
# split7_test_roc_auc                                          0.689286
# split8_test_roc_auc                                          0.721429
# split9_test_roc_auc                                          0.710714
# mean_test_roc_auc                                            0.716957
# std_test_roc_auc                                             0.066394
# rank_test_roc_auc                                                  36
#
#                                                                    33  \
# mean_fit_time                                                0.004611
# std_fit_time                                                 0.000687
# mean_score_time                                              0.003915
# std_score_time                                               0.000526
# param_logreg__C                                                 10000
# param_pca__n_components                                             2
# params                   {'logreg__C': 10000, 'pca__n_components': 2}
# split0_test_f1_macro                                         0.732989
# split1_test_f1_macro                                         0.644646
# split2_test_f1_macro                                          0.60724
# split3_test_f1_macro                                         0.705163
# split4_test_f1_macro                                          0.57931
# split5_test_f1_macro                                         0.717331
# split6_test_f1_macro                                         0.688458
# split7_test_f1_macro                                         0.534028
# split8_test_f1_macro                                          0.61875
# split9_test_f1_macro                                         0.763566
# mean_test_f1_macro                                           0.659148
# std_test_f1_macro                                            0.070202
# rank_test_f1_macro                                                 26
# split0_test_roc_auc                                          0.853409
# split1_test_roc_auc                                          0.746591
# split2_test_roc_auc                                            0.6875
# split3_test_roc_auc                                          0.821138
# split4_test_roc_auc                                          0.642857
# split5_test_roc_auc                                          0.764286
# split6_test_roc_auc                                          0.790476
# split7_test_roc_auc                                          0.613095
# split8_test_roc_auc                                          0.770238
# split9_test_roc_auc                                          0.828571
# mean_test_roc_auc                                            0.751816
# std_test_roc_auc                                             0.076346
# rank_test_roc_auc                                                  31
#
#                                                                    34  \
# mean_fit_time                                                0.004696
# std_fit_time                                                 0.000777
# mean_score_time                                              0.004398
# std_score_time                                               0.000665
# param_logreg__C                                                 10000
# param_pca__n_components                                             3
# params                   {'logreg__C': 10000, 'pca__n_components': 3}
# split0_test_f1_macro                                         0.741667
# split1_test_f1_macro                                         0.595527
# split2_test_f1_macro                                         0.594048
# split3_test_f1_macro                                          0.71634
# split4_test_f1_macro                                         0.566537
# split5_test_f1_macro                                         0.730645
# split6_test_f1_macro                                         0.646919
# split7_test_f1_macro                                         0.592246
# split8_test_f1_macro                                           0.6324
# split9_test_f1_macro                                         0.755348
# mean_test_f1_macro                                           0.657167
# std_test_f1_macro                                            0.068272
# rank_test_f1_macro                                                 31
# split0_test_roc_auc                                          0.881818
# split1_test_roc_auc                                          0.756818
# split2_test_roc_auc                                          0.745455
# split3_test_roc_auc                                          0.817654
# split4_test_roc_auc                                          0.654762
# split5_test_roc_auc                                          0.820238
# split6_test_roc_auc                                               0.8
# split7_test_roc_auc                                          0.692857
# split8_test_roc_auc                                          0.857143
# split9_test_roc_auc                                          0.835714
# mean_test_roc_auc                                            0.786246
# std_test_roc_auc                                             0.068904
# rank_test_roc_auc                                                  26
#
#                                                                    35  \
# mean_fit_time                                                0.004296
# std_fit_time                                                 0.000459
# mean_score_time                                               0.00379
# std_score_time                                               0.000396
# param_logreg__C                                                 10000
# param_pca__n_components                                             4
# params                   {'logreg__C': 10000, 'pca__n_components': 4}
# split0_test_f1_macro                                          0.76315
# split1_test_f1_macro                                         0.608586
# split2_test_f1_macro                                         0.582619
# split3_test_f1_macro                                         0.765152
# split4_test_f1_macro                                         0.592687
# split5_test_f1_macro                                         0.651009
# split6_test_f1_macro                                         0.633021
# split7_test_f1_macro                                          0.67027
# split8_test_f1_macro                                         0.646919
# split9_test_f1_macro                                         0.714572
# mean_test_f1_macro                                           0.662798
# std_test_f1_macro                                            0.062325
# rank_test_f1_macro                                                 21
# split0_test_roc_auc                                          0.888636
# split1_test_roc_auc                                          0.782955
# split2_test_roc_auc                                          0.694318
# split3_test_roc_auc                                           0.86295
# split4_test_roc_auc                                           0.67381
# split5_test_roc_auc                                          0.807143
# split6_test_roc_auc                                          0.817857
# split7_test_roc_auc                                          0.702381
# split8_test_roc_auc                                          0.860714
# split9_test_roc_auc                                          0.829762
# mean_test_roc_auc                                            0.792053
# std_test_roc_auc                                              0.07283
# rank_test_roc_auc                                                  23
#
#                                                                    36  \
# mean_fit_time                                                0.004721
# std_fit_time                                                 0.000462
# mean_score_time                                              0.003887
# std_score_time                                               0.000302
# param_logreg__C                                                 10000
# param_pca__n_components                                             5
# params                   {'logreg__C': 10000, 'pca__n_components': 5}
# split0_test_f1_macro                                         0.799589
# split1_test_f1_macro                                         0.608586
# split2_test_f1_macro                                         0.582619
# split3_test_f1_macro                                         0.741252
# split4_test_f1_macro                                         0.645349
# split5_test_f1_macro                                         0.679642
# split6_test_f1_macro                                         0.673797
# split7_test_f1_macro                                         0.709062
# split8_test_f1_macro                                         0.646919
# split9_test_f1_macro                                          0.72416
# mean_test_f1_macro                                           0.681097
# std_test_f1_macro                                            0.061443
# rank_test_f1_macro                                                 16
# split0_test_roc_auc                                          0.894318
# split1_test_roc_auc                                          0.780682
# split2_test_roc_auc                                          0.694318
# split3_test_roc_auc                                          0.858304
# split4_test_roc_auc                                           0.74881
# split5_test_roc_auc                                          0.830952
# split6_test_roc_auc                                          0.810714
# split7_test_roc_auc                                          0.707143
# split8_test_roc_auc                                          0.816667
# split9_test_roc_auc                                          0.842857
# mean_test_roc_auc                                            0.798477
# std_test_roc_auc                                             0.061842
# rank_test_roc_auc                                                  18
#
#                                                                    37  \
# mean_fit_time                                                0.004496
# std_fit_time                                                 0.000502
# mean_score_time                                              0.003754
# std_score_time                                               0.001032
# param_logreg__C                                                 10000
# param_pca__n_components                                             6
# params                   {'logreg__C': 10000, 'pca__n_components': 6}
# split0_test_f1_macro                                         0.819977
# split1_test_f1_macro                                         0.635294
# split2_test_f1_macro                                         0.682955
# split3_test_f1_macro                                         0.765152
# split4_test_f1_macro                                         0.694236
# split5_test_f1_macro                                         0.825515
# split6_test_f1_macro                                          0.72416
# split7_test_f1_macro                                         0.679642
# split8_test_f1_macro                                         0.699507
# split9_test_f1_macro                                         0.739634
# mean_test_f1_macro                                           0.726607
# std_test_f1_macro                                            0.058646
# rank_test_f1_macro                                                  6
# split0_test_roc_auc                                          0.890909
# split1_test_roc_auc                                          0.760227
# split2_test_roc_auc                                          0.745455
# split3_test_roc_auc                                          0.843206
# split4_test_roc_auc                                           0.74881
# split5_test_roc_auc                                          0.908333
# split6_test_roc_auc                                          0.864286
# split7_test_roc_auc                                          0.769048
# split8_test_roc_auc                                          0.869048
# split9_test_roc_auc                                          0.863095
# mean_test_roc_auc                                            0.826242
# std_test_roc_auc                                             0.059998
# rank_test_roc_auc                                                   1
#
#                                                                    38  \
# mean_fit_time                                                0.004306
# std_fit_time                                                 0.000651
# mean_score_time                                              0.003684
# std_score_time                                               0.000449
# param_logreg__C                                                 10000
# param_pca__n_components                                             7
# params                   {'logreg__C': 10000, 'pca__n_components': 7}
# split0_test_f1_macro                                         0.819977
# split1_test_f1_macro                                          0.62183
# split2_test_f1_macro                                         0.639954
# split3_test_f1_macro                                         0.749612
# split4_test_f1_macro                                         0.684755
# split5_test_f1_macro                                         0.790618
# split6_test_f1_macro                                         0.739573
# split7_test_f1_macro                                         0.709062
# split8_test_f1_macro                                         0.729997
# split9_test_f1_macro                                         0.739634
# mean_test_f1_macro                                           0.722501
# std_test_f1_macro                                            0.058371
# rank_test_f1_macro                                                 13
# split0_test_roc_auc                                          0.897727
# split1_test_roc_auc                                          0.768182
# split2_test_roc_auc                                          0.742045
# split3_test_roc_auc                                          0.836237
# split4_test_roc_auc                                          0.709524
# split5_test_roc_auc                                               0.9
# split6_test_roc_auc                                          0.864286
# split7_test_roc_auc                                          0.778571
# split8_test_roc_auc                                          0.858333
# split9_test_roc_auc                                              0.85
# mean_test_roc_auc                                            0.820491
# std_test_roc_auc                                             0.063021
# rank_test_roc_auc                                                  11
#
#                                                                    39
# mean_fit_time                                                 0.00428
# std_fit_time                                                 0.000467
# mean_score_time                                              0.003824
# std_score_time                                               0.000746
# param_logreg__C                                                 10000
# param_pca__n_components                                             8
# params                   {'logreg__C': 10000, 'pca__n_components': 8}
# split0_test_f1_macro                                         0.819977
# split1_test_f1_macro                                         0.635294
# split2_test_f1_macro                                         0.667857
# split3_test_f1_macro                                         0.788133
# split4_test_f1_macro                                          0.67027
# split5_test_f1_macro                                         0.871424
# split6_test_f1_macro                                          0.72416
# split7_test_f1_macro                                         0.694236
# split8_test_f1_macro                                         0.714572
# split9_test_f1_macro                                         0.761217
# mean_test_f1_macro                                           0.734714
# std_test_f1_macro                                            0.070837
# rank_test_f1_macro                                                  1
# split0_test_roc_auc                                          0.902273
# split1_test_roc_auc                                            0.7875
# split2_test_roc_auc                                          0.751136
# split3_test_roc_auc                                          0.832753
# split4_test_roc_auc                                          0.707143
# split5_test_roc_auc                                          0.916667
# split6_test_roc_auc                                           0.85119
# split7_test_roc_auc                                          0.767857
# split8_test_roc_auc                                          0.858333
# split9_test_roc_auc                                          0.855952
# mean_test_roc_auc                                             0.82308
# std_test_roc_auc                                             0.064164
# rank_test_roc_auc                                                   8
#
# [33 rows x 40 columns]

# %% [markdown]
# _Table 4: Shown here are the return values for the 10-fold grid search crossvalidation wiht f1-scoring and of the dataset using a **liblinear (l2)** solver._

# %%
print(f"The best score was of {gcv_results.best_score_:.3} from estimators {gcv_results.best_estimator_}")
# Out:
# The best score was of 0.826 from estimators Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=6)),
#                 ('logreg',
#                  LogisticRegression(C=10, random_state=1, solver='liblinear'))])

# %% [markdown]
# #### Now with 'liblinear' (l1) solver

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn.model_selection import GridSearchCV

lg_pipe = modeling_pipeline = Pipeline([
        ('scaler', StandardScaler()),
         ('pca', PCA(n_components=3)),
         ('logreg', LogisticRegression(penalty="l2", solver='lbfgs', random_state=1))
        ]
    )
        
param_grid = [
  {'logreg__C': [1, 10, 100, 1000, 10000], 'pca__n_components': [1,2,3, 4, 5, 6, 7, 8]}
 ]

gcv_results = GridSearchCV(estimator=lg_pipe, param_grid=param_grid, scoring=['f1_macro', 'roc_auc'], refit="roc_auc", cv=10)
gcv_results = gcv_results.fit(x_train, y_train)

# %%
pd.DataFrame.from_dict(gcv_results.cv_results_).T
# Out:
#                                                                0   \
# mean_fit_time                                            0.005909
# std_fit_time                                             0.000822
# mean_score_time                                          0.003892
# std_score_time                                           0.000538
# param_logreg__C                                                 1
# param_pca__n_components                                         1
# params                   {'logreg__C': 1, 'pca__n_components': 1}
# split0_test_f1_macro                                      0.69031
# split1_test_f1_macro                                     0.594771
# split2_test_f1_macro                                     0.634048
# split3_test_f1_macro                                     0.634409
# split4_test_f1_macro                                      0.46992
# split5_test_f1_macro                                      0.61875
# split6_test_f1_macro                                     0.688458
# split7_test_f1_macro                                      0.61875
# split8_test_f1_macro                                     0.582827
# split9_test_f1_macro                                     0.660734
# mean_test_f1_macro                                       0.619298
# std_test_f1_macro                                        0.060195
# rank_test_f1_macro                                             36
# split0_test_roc_auc                                      0.818182
# split1_test_roc_auc                                      0.628409
# split2_test_roc_auc                                      0.703409
# split3_test_roc_auc                                      0.788618
# split4_test_roc_auc                                      0.590476
# split5_test_roc_auc                                      0.770238
# split6_test_roc_auc                                       0.74881
# split7_test_roc_auc                                      0.689286
# split8_test_roc_auc                                      0.721429
# split9_test_roc_auc                                      0.710714
# mean_test_roc_auc                                        0.716957
# std_test_roc_auc                                         0.066394
# rank_test_roc_auc                                              36
#
#                                                                1   \
# mean_fit_time                                            0.005604
# std_fit_time                                             0.000666
# mean_score_time                                          0.004008
# std_score_time                                           0.000785
# param_logreg__C                                                 1
# param_pca__n_components                                         2
# params                   {'logreg__C': 1, 'pca__n_components': 2}
# split0_test_f1_macro                                     0.732989
# split1_test_f1_macro                                     0.644646
# split2_test_f1_macro                                      0.60724
# split3_test_f1_macro                                     0.705163
# split4_test_f1_macro                                      0.57931
# split5_test_f1_macro                                     0.717331
# split6_test_f1_macro                                     0.688458
# split7_test_f1_macro                                     0.534028
# split8_test_f1_macro                                      0.61875
# split9_test_f1_macro                                     0.763566
# mean_test_f1_macro                                       0.659148
# std_test_f1_macro                                        0.070202
# rank_test_f1_macro                                             26
# split0_test_roc_auc                                      0.853409
# split1_test_roc_auc                                      0.746591
# split2_test_roc_auc                                        0.6875
# split3_test_roc_auc                                      0.821138
# split4_test_roc_auc                                      0.642857
# split5_test_roc_auc                                      0.764286
# split6_test_roc_auc                                      0.790476
# split7_test_roc_auc                                      0.613095
# split8_test_roc_auc                                      0.770238
# split9_test_roc_auc                                      0.828571
# mean_test_roc_auc                                        0.751816
# std_test_roc_auc                                         0.076346
# rank_test_roc_auc                                              31
#
#                                                                2   \
# mean_fit_time                                            0.005914
# std_fit_time                                             0.001205
# mean_score_time                                          0.003979
# std_score_time                                           0.000995
# param_logreg__C                                                 1
# param_pca__n_components                                         3
# params                   {'logreg__C': 1, 'pca__n_components': 3}
# split0_test_f1_macro                                     0.741667
# split1_test_f1_macro                                     0.595527
# split2_test_f1_macro                                     0.594048
# split3_test_f1_macro                                      0.71634
# split4_test_f1_macro                                     0.566537
# split5_test_f1_macro                                     0.709524
# split6_test_f1_macro                                     0.646919
# split7_test_f1_macro                                     0.592246
# split8_test_f1_macro                                       0.6324
# split9_test_f1_macro                                     0.755348
# mean_test_f1_macro                                       0.655055
# std_test_f1_macro                                        0.066263
# rank_test_f1_macro                                             35
# split0_test_roc_auc                                      0.881818
# split1_test_roc_auc                                      0.756818
# split2_test_roc_auc                                      0.745455
# split3_test_roc_auc                                      0.817654
# split4_test_roc_auc                                      0.654762
# split5_test_roc_auc                                      0.820238
# split6_test_roc_auc                                           0.8
# split7_test_roc_auc                                      0.691667
# split8_test_roc_auc                                      0.855952
# split9_test_roc_auc                                      0.835714
# mean_test_roc_auc                                        0.786008
# std_test_roc_auc                                         0.068945
# rank_test_roc_auc                                              30
#
#                                                                3   \
# mean_fit_time                                              0.0062
# std_fit_time                                             0.000599
# mean_score_time                                            0.0041
# std_score_time                                             0.0003
# param_logreg__C                                                 1
# param_pca__n_components                                         4
# params                   {'logreg__C': 1, 'pca__n_components': 4}
# split0_test_f1_macro                                      0.76315
# split1_test_f1_macro                                     0.608586
# split2_test_f1_macro                                     0.582619
# split3_test_f1_macro                                     0.741252
# split4_test_f1_macro                                     0.592687
# split5_test_f1_macro                                     0.651009
# split6_test_f1_macro                                     0.633021
# split7_test_f1_macro                                      0.67027
# split8_test_f1_macro                                     0.646919
# split9_test_f1_macro                                     0.714572
# mean_test_f1_macro                                       0.660409
# std_test_f1_macro                                        0.058708
# rank_test_f1_macro                                             25
# split0_test_roc_auc                                      0.888636
# split1_test_roc_auc                                      0.782955
# split2_test_roc_auc                                      0.693182
# split3_test_roc_auc                                      0.861789
# split4_test_roc_auc                                       0.67381
# split5_test_roc_auc                                      0.808333
# split6_test_roc_auc                                      0.819048
# split7_test_roc_auc                                      0.702381
# split8_test_roc_auc                                      0.861905
# split9_test_roc_auc                                      0.829762
# mean_test_roc_auc                                         0.79218
# std_test_roc_auc                                         0.073053
# rank_test_roc_auc                                              22
#
#                                                                4   \
# mean_fit_time                                            0.006316
# std_fit_time                                             0.000671
# mean_score_time                                          0.003883
# std_score_time                                           0.000699
# param_logreg__C                                                 1
# param_pca__n_components                                         5
# params                   {'logreg__C': 1, 'pca__n_components': 5}
# split0_test_f1_macro                                     0.799589
# split1_test_f1_macro                                     0.608586
# split2_test_f1_macro                                     0.582619
# split3_test_f1_macro                                     0.741252
# split4_test_f1_macro                                     0.645349
# split5_test_f1_macro                                     0.679642
# split6_test_f1_macro                                     0.673797
# split7_test_f1_macro                                     0.684755
# split8_test_f1_macro                                     0.646919
# split9_test_f1_macro                                      0.72416
# mean_test_f1_macro                                       0.678667
# std_test_f1_macro                                        0.060766
# rank_test_f1_macro                                             20
# split0_test_roc_auc                                      0.893182
# split1_test_roc_auc                                      0.780682
# split2_test_roc_auc                                      0.693182
# split3_test_roc_auc                                      0.858304
# split4_test_roc_auc                                          0.75
# split5_test_roc_auc                                      0.830952
# split6_test_roc_auc                                      0.811905
# split7_test_roc_auc                                      0.707143
# split8_test_roc_auc                                      0.815476
# split9_test_roc_auc                                      0.842857
# mean_test_roc_auc                                        0.798368
# std_test_roc_auc                                         0.061755
# rank_test_roc_auc                                              19
#
#                                                                5   \
# mean_fit_time                                            0.007301
# std_fit_time                                              0.00064
# mean_score_time                                          0.004599
# std_score_time                                           0.000489
# param_logreg__C                                                 1
# param_pca__n_components                                         6
# params                   {'logreg__C': 1, 'pca__n_components': 6}
# split0_test_f1_macro                                     0.819977
# split1_test_f1_macro                                     0.607726
# split2_test_f1_macro                                     0.682955
# split3_test_f1_macro                                     0.765152
# split4_test_f1_macro                                     0.694236
# split5_test_f1_macro                                     0.825515
# split6_test_f1_macro                                      0.72416
# split7_test_f1_macro                                     0.694236
# split8_test_f1_macro                                     0.699507
# split9_test_f1_macro                                     0.739634
# mean_test_f1_macro                                        0.72531
# std_test_f1_macro                                        0.062461
# rank_test_f1_macro                                             11
# split0_test_roc_auc                                      0.890909
# split1_test_roc_auc                                        0.7625
# split2_test_roc_auc                                      0.744318
# split3_test_roc_auc                                      0.843206
# split4_test_roc_auc                                       0.74881
# split5_test_roc_auc                                      0.908333
# split6_test_roc_auc                                      0.861905
# split7_test_roc_auc                                      0.769048
# split8_test_roc_auc                                      0.870238
# split9_test_roc_auc                                      0.863095
# mean_test_roc_auc                                        0.826236
# std_test_roc_auc                                         0.059846
# rank_test_roc_auc                                               5
#
#                                                                6   \
# mean_fit_time                                              0.0058
# std_fit_time                                             0.000748
# mean_score_time                                          0.004002
# std_score_time                                           0.000447
# param_logreg__C                                                 1
# param_pca__n_components                                         7
# params                   {'logreg__C': 1, 'pca__n_components': 7}
# split0_test_f1_macro                                     0.819977
# split1_test_f1_macro                                      0.62183
# split2_test_f1_macro                                     0.639954
# split3_test_f1_macro                                     0.765152
# split4_test_f1_macro                                     0.684755
# split5_test_f1_macro                                     0.809645
# split6_test_f1_macro                                     0.739573
# split7_test_f1_macro                                      0.72416
# split8_test_f1_macro                                     0.729997
# split9_test_f1_macro                                     0.739634
# mean_test_f1_macro                                       0.727468
# std_test_f1_macro                                        0.061389
# rank_test_f1_macro                                              6
# split0_test_roc_auc                                      0.897727
# split1_test_roc_auc                                      0.768182
# split2_test_roc_auc                                      0.742045
# split3_test_roc_auc                                      0.837398
# split4_test_roc_auc                                      0.708333
# split5_test_roc_auc                                           0.9
# split6_test_roc_auc                                      0.861905
# split7_test_roc_auc                                      0.777381
# split8_test_roc_auc                                      0.858333
# split9_test_roc_auc                                          0.85
# mean_test_roc_auc                                        0.820131
# std_test_roc_auc                                          0.06318
# rank_test_roc_auc                                              15
#
#                                                                7   \
# mean_fit_time                                             0.00635
# std_fit_time                                             0.000635
# mean_score_time                                            0.0042
# std_score_time                                             0.0006
# param_logreg__C                                                 1
# param_pca__n_components                                         8
# params                   {'logreg__C': 1, 'pca__n_components': 8}
# split0_test_f1_macro                                     0.819977
# split1_test_f1_macro                                     0.635294
# split2_test_f1_macro                                     0.667857
# split3_test_f1_macro                                     0.788133
# split4_test_f1_macro                                      0.67027
# split5_test_f1_macro                                     0.871424
# split6_test_f1_macro                                      0.72416
# split7_test_f1_macro                                     0.694236
# split8_test_f1_macro                                     0.714572
# split9_test_f1_macro                                     0.761217
# mean_test_f1_macro                                       0.734714
# std_test_f1_macro                                        0.070837
# rank_test_f1_macro                                              1
# split0_test_roc_auc                                      0.902273
# split1_test_roc_auc                                      0.786364
# split2_test_roc_auc                                      0.753409
# split3_test_roc_auc                                      0.837398
# split4_test_roc_auc                                      0.707143
# split5_test_roc_auc                                      0.916667
# split6_test_roc_auc                                       0.85119
# split7_test_roc_auc                                      0.767857
# split8_test_roc_auc                                      0.858333
# split9_test_roc_auc                                      0.858333
# mean_test_roc_auc                                        0.823897
# std_test_roc_auc                                         0.064185
# rank_test_roc_auc                                               6
#
#                                                                 8   \
# mean_fit_time                                               0.0057
# std_fit_time                                              0.000641
# mean_score_time                                              0.004
# std_score_time                                            0.000632
# param_logreg__C                                                 10
# param_pca__n_components                                          1
# params                   {'logreg__C': 10, 'pca__n_components': 1}
# split0_test_f1_macro                                       0.69031
# split1_test_f1_macro                                      0.594771
# split2_test_f1_macro                                      0.634048
# split3_test_f1_macro                                      0.634409
# split4_test_f1_macro                                       0.46992
# split5_test_f1_macro                                       0.61875
# split6_test_f1_macro                                      0.688458
# split7_test_f1_macro                                       0.61875
# split8_test_f1_macro                                      0.582827
# split9_test_f1_macro                                      0.660734
# mean_test_f1_macro                                        0.619298
# std_test_f1_macro                                         0.060195
# rank_test_f1_macro                                              36
# split0_test_roc_auc                                       0.818182
# split1_test_roc_auc                                       0.628409
# split2_test_roc_auc                                       0.703409
# split3_test_roc_auc                                       0.788618
# split4_test_roc_auc                                       0.590476
# split5_test_roc_auc                                       0.770238
# split6_test_roc_auc                                        0.74881
# split7_test_roc_auc                                       0.689286
# split8_test_roc_auc                                       0.721429
# split9_test_roc_auc                                       0.710714
# mean_test_roc_auc                                         0.716957
# std_test_roc_auc                                          0.066394
# rank_test_roc_auc                                               36
#
#                                                                 9   ...  \
# mean_fit_time                                             0.005654  ...
# std_fit_time                                              0.000556  ...
# mean_score_time                                           0.004199  ...
# std_score_time                                             0.00087  ...
# param_logreg__C                                                 10  ...
# param_pca__n_components                                          2  ...
# params                   {'logreg__C': 10, 'pca__n_components': 2}  ...
# split0_test_f1_macro                                      0.732989  ...
# split1_test_f1_macro                                      0.644646  ...
# split2_test_f1_macro                                       0.60724  ...
# split3_test_f1_macro                                      0.705163  ...
# split4_test_f1_macro                                       0.57931  ...
# split5_test_f1_macro                                      0.717331  ...
# split6_test_f1_macro                                      0.688458  ...
# split7_test_f1_macro                                      0.534028  ...
# split8_test_f1_macro                                       0.61875  ...
# split9_test_f1_macro                                      0.763566  ...
# mean_test_f1_macro                                        0.659148  ...
# std_test_f1_macro                                         0.070202  ...
# rank_test_f1_macro                                              26  ...
# split0_test_roc_auc                                       0.853409  ...
# split1_test_roc_auc                                       0.746591  ...
# split2_test_roc_auc                                         0.6875  ...
# split3_test_roc_auc                                       0.821138  ...
# split4_test_roc_auc                                       0.642857  ...
# split5_test_roc_auc                                       0.764286  ...
# split6_test_roc_auc                                       0.790476  ...
# split7_test_roc_auc                                       0.613095  ...
# split8_test_roc_auc                                       0.770238  ...
# split9_test_roc_auc                                       0.828571  ...
# mean_test_roc_auc                                         0.751816  ...
# std_test_roc_auc                                          0.076346  ...
# rank_test_roc_auc                                               31  ...
#
#                                                                   30  \
# mean_fit_time                                                 0.0067
# std_fit_time                                                0.001005
# mean_score_time                                             0.004502
# std_score_time                                              0.000921
# param_logreg__C                                                 1000
# param_pca__n_components                                            7
# params                   {'logreg__C': 1000, 'pca__n_components': 7}
# split0_test_f1_macro                                        0.819977
# split1_test_f1_macro                                         0.62183
# split2_test_f1_macro                                        0.639954
# split3_test_f1_macro                                        0.749612
# split4_test_f1_macro                                        0.684755
# split5_test_f1_macro                                        0.790618
# split6_test_f1_macro                                        0.739573
# split7_test_f1_macro                                        0.709062
# split8_test_f1_macro                                        0.729997
# split9_test_f1_macro                                        0.739634
# mean_test_f1_macro                                          0.722501
# std_test_f1_macro                                           0.058371
# rank_test_f1_macro                                                12
# split0_test_roc_auc                                         0.897727
# split1_test_roc_auc                                         0.768182
# split2_test_roc_auc                                         0.742045
# split3_test_roc_auc                                         0.836237
# split4_test_roc_auc                                         0.709524
# split5_test_roc_auc                                              0.9
# split6_test_roc_auc                                         0.864286
# split7_test_roc_auc                                         0.778571
# split8_test_roc_auc                                         0.858333
# split9_test_roc_auc                                             0.85
# mean_test_roc_auc                                           0.820491
# std_test_roc_auc                                            0.063021
# rank_test_roc_auc                                                 11
#
#                                                                   31  \
# mean_fit_time                                               0.006398
# std_fit_time                                                0.000797
# mean_score_time                                             0.004716
# std_score_time                                              0.000467
# param_logreg__C                                                 1000
# param_pca__n_components                                            8
# params                   {'logreg__C': 1000, 'pca__n_components': 8}
# split0_test_f1_macro                                        0.819977
# split1_test_f1_macro                                        0.635294
# split2_test_f1_macro                                        0.667857
# split3_test_f1_macro                                        0.788133
# split4_test_f1_macro                                         0.67027
# split5_test_f1_macro                                        0.871424
# split6_test_f1_macro                                         0.72416
# split7_test_f1_macro                                        0.694236
# split8_test_f1_macro                                        0.714572
# split9_test_f1_macro                                        0.761217
# mean_test_f1_macro                                          0.734714
# std_test_f1_macro                                           0.070837
# rank_test_f1_macro                                                 1
# split0_test_roc_auc                                         0.902273
# split1_test_roc_auc                                           0.7875
# split2_test_roc_auc                                         0.751136
# split3_test_roc_auc                                         0.832753
# split4_test_roc_auc                                         0.707143
# split5_test_roc_auc                                         0.916667
# split6_test_roc_auc                                          0.85119
# split7_test_roc_auc                                         0.767857
# split8_test_roc_auc                                         0.858333
# split9_test_roc_auc                                         0.855952
# mean_test_roc_auc                                            0.82308
# std_test_roc_auc                                            0.064164
# rank_test_roc_auc                                                  8
#
#                                                                    32  \
# mean_fit_time                                                0.006698
# std_fit_time                                                 0.000909
# mean_score_time                                              0.004898
# std_score_time                                               0.001045
# param_logreg__C                                                 10000
# param_pca__n_components                                             1
# params                   {'logreg__C': 10000, 'pca__n_components': 1}
# split0_test_f1_macro                                          0.69031
# split1_test_f1_macro                                         0.594771
# split2_test_f1_macro                                         0.634048
# split3_test_f1_macro                                         0.634409
# split4_test_f1_macro                                          0.46992
# split5_test_f1_macro                                          0.61875
# split6_test_f1_macro                                         0.688458
# split7_test_f1_macro                                          0.61875
# split8_test_f1_macro                                         0.582827
# split9_test_f1_macro                                         0.660734
# mean_test_f1_macro                                           0.619298
# std_test_f1_macro                                            0.060195
# rank_test_f1_macro                                                 36
# split0_test_roc_auc                                          0.818182
# split1_test_roc_auc                                          0.628409
# split2_test_roc_auc                                          0.703409
# split3_test_roc_auc                                          0.788618
# split4_test_roc_auc                                          0.590476
# split5_test_roc_auc                                          0.770238
# split6_test_roc_auc                                           0.74881
# split7_test_roc_auc                                          0.689286
# split8_test_roc_auc                                          0.721429
# split9_test_roc_auc                                          0.710714
# mean_test_roc_auc                                            0.716957
# std_test_roc_auc                                             0.066394
# rank_test_roc_auc                                                  36
#
#                                                                    33  \
# mean_fit_time                                                  0.0073
# std_fit_time                                                   0.0009
# mean_score_time                                              0.004903
# std_score_time                                               0.000699
# param_logreg__C                                                 10000
# param_pca__n_components                                             2
# params                   {'logreg__C': 10000, 'pca__n_components': 2}
# split0_test_f1_macro                                         0.732989
# split1_test_f1_macro                                         0.644646
# split2_test_f1_macro                                          0.60724
# split3_test_f1_macro                                         0.705163
# split4_test_f1_macro                                          0.57931
# split5_test_f1_macro                                         0.717331
# split6_test_f1_macro                                         0.688458
# split7_test_f1_macro                                         0.534028
# split8_test_f1_macro                                          0.61875
# split9_test_f1_macro                                         0.763566
# mean_test_f1_macro                                           0.659148
# std_test_f1_macro                                            0.070202
# rank_test_f1_macro                                                 26
# split0_test_roc_auc                                          0.853409
# split1_test_roc_auc                                          0.746591
# split2_test_roc_auc                                            0.6875
# split3_test_roc_auc                                          0.821138
# split4_test_roc_auc                                          0.642857
# split5_test_roc_auc                                          0.764286
# split6_test_roc_auc                                          0.790476
# split7_test_roc_auc                                          0.613095
# split8_test_roc_auc                                          0.770238
# split9_test_roc_auc                                          0.828571
# mean_test_roc_auc                                            0.751816
# std_test_roc_auc                                             0.076346
# rank_test_roc_auc                                                  31
#
#                                                                    34  \
# mean_fit_time                                                0.006899
# std_fit_time                                                   0.0007
# mean_score_time                                              0.004701
# std_score_time                                               0.001552
# param_logreg__C                                                 10000
# param_pca__n_components                                             3
# params                   {'logreg__C': 10000, 'pca__n_components': 3}
# split0_test_f1_macro                                         0.741667
# split1_test_f1_macro                                         0.595527
# split2_test_f1_macro                                         0.594048
# split3_test_f1_macro                                          0.71634
# split4_test_f1_macro                                         0.566537
# split5_test_f1_macro                                         0.730645
# split6_test_f1_macro                                         0.646919
# split7_test_f1_macro                                         0.592246
# split8_test_f1_macro                                           0.6324
# split9_test_f1_macro                                         0.755348
# mean_test_f1_macro                                           0.657167
# std_test_f1_macro                                            0.068272
# rank_test_f1_macro                                                 31
# split0_test_roc_auc                                          0.881818
# split1_test_roc_auc                                          0.756818
# split2_test_roc_auc                                          0.745455
# split3_test_roc_auc                                          0.817654
# split4_test_roc_auc                                          0.654762
# split5_test_roc_auc                                          0.820238
# split6_test_roc_auc                                               0.8
# split7_test_roc_auc                                          0.692857
# split8_test_roc_auc                                          0.857143
# split9_test_roc_auc                                          0.835714
# mean_test_roc_auc                                            0.786246
# std_test_roc_auc                                             0.068904
# rank_test_roc_auc                                                  26
#
#                                                                    35  \
# mean_fit_time                                                0.007403
# std_fit_time                                                 0.000491
# mean_score_time                                                0.0043
# std_score_time                                                0.00064
# param_logreg__C                                                 10000
# param_pca__n_components                                             4
# params                   {'logreg__C': 10000, 'pca__n_components': 4}
# split0_test_f1_macro                                          0.76315
# split1_test_f1_macro                                         0.608586
# split2_test_f1_macro                                         0.582619
# split3_test_f1_macro                                         0.765152
# split4_test_f1_macro                                         0.592687
# split5_test_f1_macro                                         0.651009
# split6_test_f1_macro                                         0.633021
# split7_test_f1_macro                                          0.67027
# split8_test_f1_macro                                         0.646919
# split9_test_f1_macro                                         0.714572
# mean_test_f1_macro                                           0.662798
# std_test_f1_macro                                            0.062325
# rank_test_f1_macro                                                 21
# split0_test_roc_auc                                          0.888636
# split1_test_roc_auc                                          0.782955
# split2_test_roc_auc                                          0.694318
# split3_test_roc_auc                                           0.86295
# split4_test_roc_auc                                           0.67381
# split5_test_roc_auc                                          0.807143
# split6_test_roc_auc                                          0.817857
# split7_test_roc_auc                                          0.702381
# split8_test_roc_auc                                          0.860714
# split9_test_roc_auc                                          0.829762
# mean_test_roc_auc                                            0.792053
# std_test_roc_auc                                              0.07283
# rank_test_roc_auc                                                  23
#
#                                                                    36  \
# mean_fit_time                                                0.006797
# std_fit_time                                                 0.000748
# mean_score_time                                              0.004702
# std_score_time                                                 0.0009
# param_logreg__C                                                 10000
# param_pca__n_components                                             5
# params                   {'logreg__C': 10000, 'pca__n_components': 5}
# split0_test_f1_macro                                         0.799589
# split1_test_f1_macro                                         0.608586
# split2_test_f1_macro                                         0.582619
# split3_test_f1_macro                                         0.741252
# split4_test_f1_macro                                         0.645349
# split5_test_f1_macro                                         0.679642
# split6_test_f1_macro                                         0.673797
# split7_test_f1_macro                                         0.709062
# split8_test_f1_macro                                         0.646919
# split9_test_f1_macro                                          0.72416
# mean_test_f1_macro                                           0.681097
# std_test_f1_macro                                            0.061443
# rank_test_f1_macro                                                 16
# split0_test_roc_auc                                          0.894318
# split1_test_roc_auc                                          0.780682
# split2_test_roc_auc                                          0.694318
# split3_test_roc_auc                                          0.858304
# split4_test_roc_auc                                           0.74881
# split5_test_roc_auc                                          0.830952
# split6_test_roc_auc                                          0.810714
# split7_test_roc_auc                                          0.707143
# split8_test_roc_auc                                          0.816667
# split9_test_roc_auc                                          0.842857
# mean_test_roc_auc                                            0.798477
# std_test_roc_auc                                             0.061842
# rank_test_roc_auc                                                  17
#
#                                                                    37  \
# mean_fit_time                                                  0.0065
# std_fit_time                                                 0.000805
# mean_score_time                                              0.004204
# std_score_time                                                 0.0004
# param_logreg__C                                                 10000
# param_pca__n_components                                             6
# params                   {'logreg__C': 10000, 'pca__n_components': 6}
# split0_test_f1_macro                                         0.819977
# split1_test_f1_macro                                         0.635294
# split2_test_f1_macro                                         0.682955
# split3_test_f1_macro                                         0.765152
# split4_test_f1_macro                                         0.694236
# split5_test_f1_macro                                         0.825515
# split6_test_f1_macro                                          0.72416
# split7_test_f1_macro                                         0.679642
# split8_test_f1_macro                                         0.699507
# split9_test_f1_macro                                         0.739634
# mean_test_f1_macro                                           0.726607
# std_test_f1_macro                                            0.058646
# rank_test_f1_macro                                                  7
# split0_test_roc_auc                                          0.890909
# split1_test_roc_auc                                          0.760227
# split2_test_roc_auc                                          0.745455
# split3_test_roc_auc                                          0.843206
# split4_test_roc_auc                                           0.74881
# split5_test_roc_auc                                          0.908333
# split6_test_roc_auc                                          0.864286
# split7_test_roc_auc                                          0.769048
# split8_test_roc_auc                                          0.869048
# split9_test_roc_auc                                          0.863095
# mean_test_roc_auc                                            0.826242
# std_test_roc_auc                                             0.059998
# rank_test_roc_auc                                                   1
#
#                                                                    38  \
# mean_fit_time                                                0.006587
# std_fit_time                                                  0.00103
# mean_score_time                                              0.004906
# std_score_time                                               0.000526
# param_logreg__C                                                 10000
# param_pca__n_components                                             7
# params                   {'logreg__C': 10000, 'pca__n_components': 7}
# split0_test_f1_macro                                         0.819977
# split1_test_f1_macro                                          0.62183
# split2_test_f1_macro                                         0.639954
# split3_test_f1_macro                                         0.749612
# split4_test_f1_macro                                         0.684755
# split5_test_f1_macro                                         0.790618
# split6_test_f1_macro                                         0.739573
# split7_test_f1_macro                                         0.709062
# split8_test_f1_macro                                         0.729997
# split9_test_f1_macro                                         0.739634
# mean_test_f1_macro                                           0.722501
# std_test_f1_macro                                            0.058371
# rank_test_f1_macro                                                 12
# split0_test_roc_auc                                          0.897727
# split1_test_roc_auc                                          0.768182
# split2_test_roc_auc                                          0.742045
# split3_test_roc_auc                                          0.836237
# split4_test_roc_auc                                          0.709524
# split5_test_roc_auc                                               0.9
# split6_test_roc_auc                                          0.864286
# split7_test_roc_auc                                          0.778571
# split8_test_roc_auc                                          0.858333
# split9_test_roc_auc                                              0.85
# mean_test_roc_auc                                            0.820491
# std_test_roc_auc                                             0.063021
# rank_test_roc_auc                                                  11
#
#                                                                    39
# mean_fit_time                                                0.007402
# std_fit_time                                                 0.001111
# mean_score_time                                                 0.005
# std_score_time                                               0.000636
# param_logreg__C                                                 10000
# param_pca__n_components                                             8
# params                   {'logreg__C': 10000, 'pca__n_components': 8}
# split0_test_f1_macro                                         0.819977
# split1_test_f1_macro                                         0.635294
# split2_test_f1_macro                                         0.667857
# split3_test_f1_macro                                         0.788133
# split4_test_f1_macro                                         0.656015
# split5_test_f1_macro                                         0.871424
# split6_test_f1_macro                                          0.72416
# split7_test_f1_macro                                         0.694236
# split8_test_f1_macro                                         0.714572
# split9_test_f1_macro                                         0.761217
# mean_test_f1_macro                                           0.733288
# std_test_f1_macro                                            0.072248
# rank_test_f1_macro                                                  5
# split0_test_roc_auc                                          0.902273
# split1_test_roc_auc                                            0.7875
# split2_test_roc_auc                                          0.751136
# split3_test_roc_auc                                          0.832753
# split4_test_roc_auc                                          0.707143
# split5_test_roc_auc                                          0.916667
# split6_test_roc_auc                                           0.85119
# split7_test_roc_auc                                          0.767857
# split8_test_roc_auc                                          0.858333
# split9_test_roc_auc                                          0.855952
# mean_test_roc_auc                                             0.82308
# std_test_roc_auc                                             0.064164
# rank_test_roc_auc                                                   8
#
# [33 rows x 40 columns]

# %% [markdown]
# _Table 4: Shown here are the return values for the 10-fold grid search crossvalidation wiht f1-scoring and of the dataset using a **nliblinear (l1)** estimator._

# %%
print(f"The best score was of {gcv_results.best_score_:.3} from estimators {gcv_results.best_estimator_}")
# Out:
# The best score was of 0.826 from estimators Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=6)),
#                 ('logreg', LogisticRegression(C=10, random_state=1))])

# %% [markdown]
# The overall scores, best PCA components, and regularizatio nstrength do not differ. So To choose the 'best' model would be the one with the fewest entires in code length and thus the second gcv wtih _Pipeline(steps=[('scaler', StandardScaler()), ('pca', PCA(n_components=6)), ('logreg', LogisticRegression(C=10, random_state=1))])_ would suffice.
