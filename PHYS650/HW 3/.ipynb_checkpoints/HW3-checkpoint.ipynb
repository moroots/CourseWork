# %% [markdown]
# # PHYS650: Homework 3
# AERONET Data Analysis

# %% [markdown]
# ---
# ### 1) You will analyze AERONET data from two sites: https://aeronet.gsfc.nasa.gov/cgi-bin/bamgomas_interactive Plot (or copy image) and analyze AOD and Angstrom exponent for 2021 at these two sites. Briefly  describe similarities and explain differences in aerosol properties measured at these two sites. HINT: Take a look at other AERONET aerosol products.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"20210501_20210531_CCNY.lev10", sep=",", skiprows=6)
df.head()
# Out:
#   Date(dd:mm:yyyy) Time(hh:mm:ss)  Day_of_Year  Day_of_Year(Fraction)  \
# 0       01:05:2021       13:33:36          121             121.565000
# 1       01:05:2021       13:38:36          121             121.568472
# 2       01:05:2021       13:43:37          121             121.571956
# 3       01:05:2021       13:48:37          121             121.575428
# 4       01:05:2021       13:53:37          121             121.578900
#
#    AOD_1640nm  AOD_1020nm  AOD_870nm  AOD_865nm  AOD_779nm  AOD_675nm  ...  \
# 0    0.012067    0.026773   0.029920     -999.0     -999.0   0.038572  ...
# 1    0.013065    0.028143   0.031041     -999.0     -999.0   0.040078  ...
# 2    0.013338    0.028920   0.031309     -999.0     -999.0   0.040934  ...
# 3    0.012659    0.028173   0.031251     -999.0     -999.0   0.039949  ...
# 4    0.012728    0.028366   0.030823     -999.0     -999.0   0.039900  ...
#
#    Exact_Wavelengths_of_AOD(um)_380nm  Exact_Wavelengths_of_AOD(um)_340nm  \
# 0                              0.3793                              0.3399
# 1                              0.3793                              0.3399
# 2                              0.3793                              0.3399
# 3                              0.3793                              0.3399
# 4                              0.3793                              0.3399
#
#    Exact_Wavelengths_of_PW(um)_935nm  Exact_Wavelengths_of_AOD(um)_681nm  \
# 0                             0.9373                              -999.0
# 1                             0.9373                              -999.0
# 2                             0.9373                              -999.0
# 3                             0.9373                              -999.0
# 4                             0.9373                              -999.0
#
#    Exact_Wavelengths_of_AOD(um)_709nm  Exact_Wavelengths_of_AOD(um)_Empty  \
# 0                              -999.0                              -999.0
# 1                              -999.0                              -999.0
# 2                              -999.0                              -999.0
# 3                              -999.0                              -999.0
# 4                              -999.0                              -999.0
#
#    Exact_Wavelengths_of_AOD(um)_Empty.1  Exact_Wavelengths_of_AOD(um)_Empty.2  \
# 0                                -999.0                                -999.0
# 1                                -999.0                                -999.0
# 2                                -999.0                                -999.0
# 3                                -999.0                                -999.0
# 4                                -999.0                                -999.0
#
#    Exact_Wavelengths_of_AOD(um)_Empty.3  Exact_Wavelengths_of_AOD(um)_Empty.4
# 0                                -999.0                                -999.0
# 1                                -999.0                                -999.0
# 2                                -999.0                                -999.0
# 3                                -999.0                                -999.0
# 4                                -999.0                                -999.0
#
# [5 rows x 113 columns]

# %%
columns = df.columns.to_list()
time = [f"{df[columns[0]}"]
